# %%
import seaborn as sb
import pandas as pd
import matplotlib.pyplot as plt
import numpy
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('../data/sales_predictions.csv')
data.describe()
dataSampled = data.sample(50)
dataSampled.info
# Out:
# <bound method DataFrame.info of                date  date_block_num  shop_id  item_id  item_price  \
# 968419   19.10.2013               9       30     4845     2199.00
# 2205568  25.12.2014              23       42     5823     2599.00
# 1105070  20.11.2013              10       57    17346      391.00
# 529372   10.05.2013               4       50     2929      199.00
# 914789   26.09.2013               8       28     7359      199.00
# 807141   20.08.2013               7       28     8687      199.00
# 725031   04.07.2013               6       52    10957      799.00
# 1306455  27.01.2014              12       30    14224      299.00
# 530811   11.05.2013               4        6      825      299.00
# 1514546  31.03.2014              14       27    12926      399.00
# 1644596  20.05.2014              16       29     1024      599.00
# 591138   08.06.2013               5       19     5821      599.00
# 1156468  22.12.2013              11       28     6911      599.00
# ...

# %%
sb.relplot(x='date', y='item_price', data=data.sample(150))

# %%
f, ax = plt.subplots(figsize=(20,6))
sb.relplot(x="date", y="item_price", data = dataSampled, kind="line", ax = ax)
plt.show()

# %%
dataSampled['date'] = pd.to_datetime(dataSampled['date'])
dataSampled.info
# Out:
# <bound method DataFrame.info of               date  date_block_num  shop_id  item_id  item_price  item_cnt_day
# 968419  2013-10-19               9       30     4845     2199.00           1.0
# 2205568 2014-12-25              23       42     5823     2599.00           1.0
# 1105070 2013-11-20              10       57    17346      391.00           5.0
# 529372  2013-10-05               4       50     2929      199.00           3.0
# 914789  2013-09-26               8       28     7359      199.00           1.0
# 807141  2013-08-20               7       28     8687      199.00           1.0
# 725031  2013-04-07               6       52    10957      799.00           1.0
# 1306455 2014-01-27              12       30    14224      299.00           1.0
# 530811  2013-11-05               4        6      825      299.00           1.0
# 1514546 2014-03-31              14       27    12926      399.00           1.0
# ...

# %%
sb.relplot(x='date', y="item_price", data = dataSampled, kind="line", ax = ax)
